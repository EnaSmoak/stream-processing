# %%
import json

from enricher import join_to_poi
from looper_scraper import scrape_looper

# %%
looper = scrape_looper(pages=1, add_gps=True)
# Out:
# Getting page 1 from looperghana

# %%
final = join_to_poi(looper, k=3)

# %% [markdown]
# When k>1, notice the id appears multiple times but the points of interest are different

# %%
final
# Out:
#       id     source  description   price currency    area  beds showers  \
# 6   c18o  loopghana          NaN    3000        $    254     4       4
# 6   c18o  loopghana          NaN    3000        $    254     4       4
# 6   c18o  loopghana          NaN    3000        $    254     4       4
# 17  c1c4  loopghana          NaN    5500        $    312     4       4
# 17  c1c4  loopghana          NaN    5500        $    312     4       4
# 17  c1c4  loopghana          NaN    5500        $    312     4       4
# 16  c1d8  loopghana          NaN    5500        $    295     4       4
# 16  c1d8  loopghana          NaN    5500        $    295     4       4
# 16  c1d8  loopghana          NaN    5500        $    295     4       4
# 18  c1fb  loopghana          NaN   84000        $     85     2       2
# 18  c1fb  loopghana          NaN   84000        $     85     2       2
# 18  c1fb  loopghana          NaN   84000        $     85     2       2
# ...
